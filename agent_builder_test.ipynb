# %% [markdown]
# # Grounding Test

# %%
# %%writefile grounding.py

import vertexai

from vertexai.generative_models import (
    GenerationConfig,
    GenerativeModel,
    Tool,
    grounding,
)

PROJECT_ID = 'jerry-argolis'

# TODO(developer): Update and un-comment below line
# PROJECT_ID = "your-project-id"
vertexai.init(project=PROJECT_ID, location="us-central1")

model = GenerativeModel("gemini-1.5-flash-001")

# Use Google Search for grounding
tool = Tool.from_google_search_retrieval(grounding.GoogleSearchRetrieval())

prompt = "When is the next total solar eclipse in US?"
response = model.generate_content(
    prompt,
    # tools=[tool],
    generation_config=GenerationConfig(
        temperature=0.0,
    ),
)

print("-" * 20)
print(f"No grounding: {prompt}")
print("-" * 20)

print(response.text)
# Without Grounding:
# The next total solar eclipse visible in the United States will be on **April 8, 2024**.
# The path of totality will cross the country from Texas to Maine, with the longest duration of totality occurring in Mexico.

prompt = "When is the next total solar eclipse in US?"
response = model.generate_content(
    prompt,
    tools=[tool],
    generation_config=GenerationConfig(
        temperature=0.0,
    ),
)

print("-" * 20)
print(f"With grounding: {prompt}")
print("-" * 20)

print(response.text)
# With Grounding:
# The next total solar eclipse visible from the contiguous United States will be on **August 23, 2044**.



prompt = "이정재가 출연한 스타워즈 시리즈가 뭐지? 자세한 스토리와 캐스팅 과정 알려줘"
response = model.generate_content(
    prompt,
    # tools=[tool],
    generation_config=GenerationConfig(
        temperature=0.0,
    ),
)

print("-" * 20)
print(f"No grounding: {prompt}")
print("-" * 20)

print(response.text)


prompt = "이정재가 출연한 스타워즈 시리즈가 뭐지? 자세한 스토리와 캐스팅 과정 알려줘"
response = model.generate_content(
    prompt,
    tools=[tool],
    generation_config=GenerationConfig(
        temperature=0.0,
    ),
)

print("-" * 20)
print(f"With grounding: {prompt}")
print("-" * 20)

print(response.text)
# Out:
# Overwriting grounding.py

# %%
# !python3 grounding.py
# Out:
# /usr/local/lib/python3.10/dist-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# --------------------
# No grounding: When is the next total solar eclipse in US?
# --------------------
# The next total solar eclipse visible in the United States will be on **April 8, 2024**.
#
# The path of totality will cross the country from Texas to Maine, with the longest duration of totality occurring in Mexico.
#
# --------------------
# With grounding: When is the next total solar eclipse in US?
# --------------------
# The next total solar eclipse visible in the contiguous United States will be on **August 23, 2044**. It will be visible in Montana, North Dakota, and South Dakota.
#
# --------------------
# No grounding: 이정재가 출연한 스타워즈 시리즈가 뭐지? 자세한 스토리와 캐스팅 과정 알려줘
# --------------------
#  이정재는 스타워즈 시리즈에 출연한 적이 없습니다. 이정재는 한국 배우로, 주로 한국 영화와 드라마에 출연합니다. 스타워즈 시리즈는 미국 영화로, 주로 미국 배우들이 출연합니다.
#
# 혹시 이정재가 출연한 다른 영화나 드라마에 대해 궁금하신가요? 혹은 스타워즈 시리즈에 대한 정보를 원하시나요?
#
# --------------------
# With grounding: 이정재가 출연한 스타워즈 시리즈가 뭐지? 자세한 스토리와 캐스팅 과정 알려줘
# --------------------
# 이정재가 출연한 스타워즈 시리즈는 '애콜라이트'입니다. 이 드라마는 1999년 개봉한 영화 '스타워즈: 에피소드 1 - 보이지 않는 위험'의 100년 전 이야기를 다룹니다. 이정재는 제다이 역할을 맡았으며, 8개의 에피소드로 구성된 이 드라마는 디즈니 플러스에서 순차적으로 공개되었습니다.
#
# 이정재는 '애콜라이트' 출연 제안을 받고 처음에는 믿기지 않았다고 밝혔습니다. 그는 대본이 흥미로웠고, 우주에서 펼쳐지는 이야기를 그려 상상력이 폭발하는 느낌이었다고 설명했습니다. 이정재는 어린 시절 '스타워즈' 포스터를 보고 광선검을 든 배우에 대한 꿈을 키웠고, 처음 '스타워즈' 영화를 보고 스케일과 디테일에 충격을 받았던 경험을 이야기하기도 했습니다.
#
# '애콜라이트'는 이정재의 첫 번째 할리우드 진출 작품으로, 한국 배우 최초로 '스타워즈' 시리즈에 출연하게 되어 큰 화제를 모았습니다. 이정재의 화려한 액션과 연기는 제작진과 배우들로부터 극찬을 받았으며, '애콜라이트'는 디즈니 플러스의 올해 최고 흥행작이 되었습니다.

# %% [markdown]
# # 구글 맵 API 테스트

# %%
from google.colab import userdata
google_map_api_key = userdata.get('google-map-api-key')

# %%
import requests

activity = "호텔"
city = "부산"
text_query = f"{activity} in {city}"
places_resp = requests.get(
    f"https://maps.googleapis.com/maps/api/place/textsearch/json",
    params={
        "query": text_query,
        "key": google_map_api_key,
        "language": "ko",
        # "region": "KR",
    },
)
places_resp.json()
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AdCG2DNV3W67AW1UPTbNhafP2RvI5CeZ1wWLua8LMUVNAeY52uJfzWr6lQ9V-vapwzQD9-FPJlBMw8IIW-n3BO8tonTKgy3G-FMKFMl7jpx2vID-yfE1LeUF4YI3kJzPofdAQW1MfWaYYwA3smzG7U_rMFtBkLyROZpruqTiEtRSzUByk38VtTszZLa2ApEMGpySnizJrYJwPlPwavsIx6uqwURhc0ZRGdieSCC9pzDmkR5w5T7CI-i8rs4OCMBfcj5masKFcs5rXrRc_kkFYh7cwQ78-jXXZR2WKsTtGtemy5fl9UTUb3YIlbph9neBHm5edV_ZbjG9IaJB0UzlYlnUBvzbzHpfbVQMPRG3ieFmBBk8m4e1WIGGgEQREflJ98KjCyNSlPMEMe9mCkU',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 부산진구 가야대로 772',
#    'geometry': {'location': {'lat': 35.156766, 'lng': 129.05587},
#     'viewport': {'northeast': {'lat': 35.15811582989272,
#       'lng': 129.0572198298927},
#      'southwest': {'lat': 35.15541617010728, 'lng': 129.0545201701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '롯데호텔 부산',
#    'photos': [{'height': 2252,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118295300702597776773">이정일</a>'],
#      'photo_reference': 'AdCG2DMuchA0Il9cEwbc2YSIcM-K_pAllPEZZPy4PBXesAJ4zBWxrPJ0CNL9nEW012uFvP06XhQJo27gDewF3c4xKMIkgG5mOm3rQFhRHmbv4HDuD7_jw31LLRG2baal1pQIERBmLlfbwHi5zUOPcJ6nKq8ysVu2ZWfING6azViB1eHWxnmS',
#      'width': 4000}],
#    'place_id': 'ChIJzZl9PXLraDURpgeBSXYqYSQ',
#    'plus_code': {'compound_code': '5344+P8 부산광역시 대한민국',
#     'global_code': '8Q7F5344+P8'},
#    'rating': 4.4,
#    'reference': 'ChIJzZl9PXLraDURpgeBSXYqYSQ',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4640},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 달맞이길 30',
#    'geometry': {'location': {'lat': 35.1599375, 'lng': 129.1698125},
#     'viewport': {'northeast': {'lat': 35.16128732989272,
#       'lng': 129.1711623298928},
#      'southwest': {'lat': 35.15858767010727, 'lng': 129.1684626701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '시그니엘 부산',
#    'photos': [{'height': 9000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115668563197147877855">박성모</a>'],
#      'photo_reference': 'AdCG2DNrDLLRfAf98A5FdFF9aTQ-ieYd6ynZZwYBG7o0UclABHIFga5Q21ZADH0k8DeXhb7TL1uiq0Dsk0Xwljz-V6HowoMvnYBnd9bbvdyudyl0T_R3yPDv6PdBEkUMVIoSE4yAJxlYD2DyGLegu9ZU1g7F7Df0lOfKsUj4QAb4AjBJv44a',
#      'width': 12000}],
#    'place_id': 'ChIJSSysvS6NaDURhr99N981zfQ',
#    'plus_code': {'compound_code': '5559+XW 부산광역시 대한민국',
#     'global_code': '8Q7F5559+XW'},
#    'rating': 4.6,
#    'reference': 'ChIJSSysvS6NaDURhr99N981zfQ',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1239},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 해운대로570번길 46',
#    'geometry': {'location': {'lat': 35.1598682, 'lng': 129.1586644},
#     'viewport': {'northeast': {'lat': 35.16121802989272,
#       'lng': 129.1600142298927},
#      'southwest': {'lat': 35.15851837010727, 'lng': 129.1573145701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '신라스테이 해운대',
#    'photos': [{'height': 2252,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116240463170461602961">incheon kim</a>'],
#      'photo_reference': 'AdCG2DPRObDI_1Bgopx41RhVB4QmSljMCDsnTX_k4U9UzuR0V3kNxaD2xCPf7vlDiy8vfHSph5ARU52IS5a9uAwM0BDvjivNHKRSnbQemtDwfDoupXbA3mOPNHmTZKAG58Nf74rNtfq4N4GBuo491k19e_KeF9j6AoyRDVKfQIwP9X4CsjLD',
#      'width': 4000}],
#    'place_id': 'ChIJCRw0u16NaDURKZnPabmjQDw',
#    'plus_code': {'compound_code': '5555+WF 부산광역시 대한민국',
#     'global_code': '8Q7F5555+WF'},
#    'rating': 4.2,
#    'reference': 'ChIJCRw0u16NaDURKZnPabmjQDw',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3366},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 해운대해변로 296',
#    'geometry': {'location': {'lat': 35.1601338, 'lng': 129.1646875},
#     'viewport': {'northeast': {'lat': 35.16148362989271,
#       'lng': 129.1660373298927},
#      'southwest': {'lat': 35.15878397010727, 'lng': 129.1633376701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '파라다이스 호텔 부산',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 723,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117609950133837608294">A Google User</a>'],
#      'photo_reference': 'AdCG2DPFB6GfjwAfMcKBANs-uGN05TvyrNzDu2i7Wv-q7k8Rr69RVMC-Yzo7QtbgOn20PU43GK6zVYntrcBxNw-uRII17HtlqYhU5EzHPPGCofYbKFXiD3rdFok_bSj8r7ynWdUE-XiThJZAPDNm__9hwI4LQua5yMqlRMS9lxgGpQMAgvAN',
#      'width': 1200}],
#    'place_id': 'ChIJcewmsUKNaDURvdd647woro8',
#    'plus_code': {'compound_code': '5567+3V 부산광역시 대한민국',
#     'global_code': '8Q7F5567+3V'},
#    'rating': 4.5,
#    'reference': 'ChIJcewmsUKNaDURvdd647woro8',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6541},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 수영구 광안해변로 203',
#    'geometry': {'location': {'lat': 35.1525025, 'lng': 129.1174325},
#     'viewport': {'northeast': {'lat': 35.15385232989272,
#       'lng': 129.1187823298927},
#      'southwest': {'lat': 35.15115267010728, 'lng': 129.1160826701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '호텔1',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112418776353878965782">Jangwon Heo</a>'],
#      'photo_reference': 'AdCG2DOD5KjRa-9B4nT6DlJyZTacSdU2o30GrkJwg7WYtnU7nqCtNxnPmFLWvYRD-QNDNW1DKOUq9hiLU2Y_mz8nVVlYT8znD4J5N9BQIneqyBS2FV64lDFzExUyUN0TFWU3z4DoKJ2aBhxko38y3bvnzFRZQx_Iz_7ANpjF4d1oIWkvdelh',
#      'width': 4032}],
#    'place_id': 'ChIJ5S6_tyjtaDUR2A5jt3nQLCo',
#    'plus_code': {'compound_code': '5438+2X 부산광역시 대한민국',
#     'global_code': '8Q7F5438+2X'},
#    'rating': 4.7,
#    'reference': 'ChIJ5S6_tyjtaDUR2A5jt3nQLCo',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2185},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 연제구 신촌로 19',
#    'geometry': {'location': {'lat': 35.1827768, 'lng': 129.0762561},
#     'viewport': {'northeast': {'lat': 35.18412662989272,
#       'lng': 129.0776059298927},
#      'southwest': {'lat': 35.18142697010727, 'lng': 129.0749062701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '부산시티호텔',
#    'photos': [{'height': 480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114309241486696830590">A Google User</a>'],
#      'photo_reference': 'AdCG2DOYAe69V2WCuvVt6uOF2-nm9xh650rayPFsyJo-w3aeSdkZSLWDfN0Wf8BNQHYCO-1b1NzkpIJ_Ee7GYhipJ1bEDfHE3TYgK-ov4JDRwbQ17ojZ31x91T4zFAxa0kFYe07HTdmAAnF4cpQHA1I4Bbad3mBgskzdt4pI8o5bkaqYdLxR',
#      'width': 720}],
#    'place_id': 'ChIJiyI1zFaTaDURC8fhhWE2Gmo',
#    'plus_code': {'compound_code': '53MG+4G 부산광역시 대한민국',
#     'global_code': '8Q7F53MG+4G'},
#    'rating': 4.4,
#    'reference': 'ChIJiyI1zFaTaDURC8fhhWE2Gmo',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 118},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 중구 해관로 20',
#    'geometry': {'location': {'lat': 35.1003571, 'lng': 129.0359264},
#     'viewport': {'northeast': {'lat': 35.10170692989272,
#       'lng': 129.0372762298927},
#      'southwest': {'lat': 35.09900727010727, 'lng': 129.0345765701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '센트럴파크 호텔 부산',
#    'photos': [{'height': 810,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108030772911489538190">A Google User</a>'],
#      'photo_reference': 'AdCG2DOXkmTTr88WyLoI1XqHVe9vtE6kkfwmSz1UKl7xdDvfFYicxetf18RUl6gFI1lrOjn4YzV7oTd4EQ5jkExuLH_k1dksHRHFD6u1HecE_qCx9GfDUablh770QDeNSUczwlD4mWg9YnCKw1yDilQM9fDoPvjcwoN_unEzO1UKdRc_FaC5',
#      'width': 1438}],
#    'place_id': 'ChIJKwZdC3PpaDURxq_9oX0gTB8',
#    'plus_code': {'compound_code': '422P+49 부산광역시 대한민국',
#     'global_code': '8Q7F422P+49'},
#    'rating': 4.1,
#    'reference': 'ChIJKwZdC3PpaDURxq_9oX0gTB8',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 496},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 부산진구 서면문화로 26',
#    'geometry': {'location': {'lat': 35.1596883, 'lng': 129.056343},
#     'viewport': {'northeast': {'lat': 35.16103812989272,
#       'lng': 129.0576928298927},
#      'southwest': {'lat': 35.15833847010728, 'lng': 129.0549931701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '경성여관',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115833210399767313647">Benjamin Wauman</a>'],
#      'photo_reference': 'AdCG2DMBhsVIWSUcfGtusuKoo8c0oZiSH0RY5SQVYtL2IW7pxqdkF1P_8KneA98o3KjNSnL_Iud_9NzTU_HK6ia2fvLFgMTT8R9Chw-d57Fl_eIn7VsamnEnshQW3KvC0OsZEPNEYRuXPrWMB0I3N-koQHGQFm9pF259CWsv0Y5uKBFLYWak',
#      'width': 4032}],
#    'place_id': 'ChIJGQnvCPvraDURi4j-gqrJgC0',
#    'plus_code': {'compound_code': '5354+VG 부산광역시 대한민국',
#     'global_code': '8Q7F5354+VG'},
#    'rating': 4.4,
#    'reference': 'ChIJGQnvCPvraDURi4j-gqrJgC0',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 205},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 해운대해변로 292',
#    'geometry': {'location': {'lat': 35.1600161, 'lng': 129.1630504},
#     'viewport': {'northeast': {'lat': 35.16136592989272,
#       'lng': 129.1644002298927},
#      'southwest': {'lat': 35.15866627010728, 'lng': 129.1617005701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '그랜드 조선 부산',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 690,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110716818702232245688">A Google User</a>'],
#      'photo_reference': 'AdCG2DOD3C83W-983Nc8e7vhOk4Nr7gJ63g1lYqU04iaZ_bRpHRZ3ROcE5bBJG7DZHBZniev4kulKj1g6Wm1lZzuIRiC4O5CwIoKxckJWeimzgF_fjEVW23b5kEOQgA7FySO7vyqnQlxFn_k265nFTExZ0k8XDvpRbwl0m8Iyjtna94PTT4X',
#      'width': 920}],
#    'place_id': 'ChIJ168DGl2NaDURov_XuLGtvOU',
#    'plus_code': {'compound_code': '5567+26 부산광역시 대한민국',
#     'global_code': '8Q7F5567+26'},
#    'rating': 4.3,
#    'reference': 'ChIJ168DGl2NaDURov_XuLGtvOU',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2339},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 중구 자갈치로 21',
#    'geometry': {'location': {'lat': 35.0966908, 'lng': 129.0266708},
#     'viewport': {'northeast': {'lat': 35.09804062989273,
#       'lng': 129.0280206298928},
#      'southwest': {'lat': 35.09534097010728, 'lng': 129.0253209701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '오션투헤븐호텔&스파',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100707655436578793054">A Google User</a>'],
#      'photo_reference': 'AdCG2DOYjC_-Tt023TrxmPky5JHOG17qkl0-ZvmbUMi0oJJmnR6GQRleSfqUeqiwHLUhhwQAzMyK-IWAWBMZ6AJsnTV2CTM6cZikFsvT2oWp_qJgws49CS0vI6TlnxaSkPwurGGMYYO-v3xk_UOS4e8vRG5c-WRURW9RgL9YSEbxMHLoEHbh',
#      'width': 720}],
#    'place_id': 'ChIJe_GLeLLpaDURqLVwhDY7r4c',
#    'plus_code': {'compound_code': '32WG+MM 부산광역시 대한민국',
#     'global_code': '8Q7F32WG+MM'},
#    'rating': 4.6,
#    'reference': 'ChIJe_GLeLLpaDURqLVwhDY7r4c',
#    'types': ['spa', 'lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 151},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 부산진구 중앙대로691번길 32',
#    'geometry': {'location': {'lat': 35.1545767, 'lng': 129.0573613},
#     'viewport': {'northeast': {'lat': 35.15592652989272,
#       'lng': 129.0587111298927},
#      'southwest': {'lat': 35.15322687010728, 'lng': 129.0560114701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '아르반호텔',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3648,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101512152103739911122">아르반호텔</a>'],
#      'photo_reference': 'AdCG2DMTJWO17Azft8XOoNueW4eKTybBW3WCCbKNlIu5mRNylU8GZUN7ru3xjyzyh9xwpHR4CAIr5_CNqh9a3pIZXd4KAqB2z8jRWohe6FutNaEdkCQNqsh8Et8Tyq8AeWLl3H_6UJXGnC95Zllttzq6z8qhu3huAkh0QDCEF-x86nrKEUQ1',
#      'width': 5472}],
#    'place_id': 'ChIJYYpkx3HraDURgvh1VdVn5mw',
#    'plus_code': {'compound_code': '5334+RW 부산광역시 대한민국',
#     'global_code': '8Q7F5334+RW'},
#    'rating': 4.3,
#    'reference': 'ChIJYYpkx3HraDURgvh1VdVn5mw',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1164},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 구남로21번길 6',
#    'geometry': {'location': {'lat': 35.16227629999999, 'lng': 129.1607992},
#     'viewport': {'northeast': {'lat': 35.16362612989272,
#       'lng': 129.1621490298927},
#      'southwest': {'lat': 35.16092647010728, 'lng': 129.1594493701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '엘본더스테이',
#    'photos': [{'height': 5712,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113977198446880782562">A Google User</a>'],
#      'photo_reference': 'AdCG2DM-9krbkiFBRnppA-_uPcB_V12FnQ-wSLS0ZyF7QbaOaW97HN09bf9gL-joeg6oBmFcEEjKnsUatR8IzEXoGZo6Yt5RMVmGGSdN72KxXP4V9aitrxS39Tzwm_LdRD5JwS2wYG6mTGiRxAytIye5uSFrP5rXWxP6aQMFd-hS5KhSHh8V',
#      'width': 4284}],
#    'place_id': 'ChIJERqgfIiNaDURQ9y73Ki1tdM',
#    'plus_code': {'compound_code': '5566+W8 부산광역시 대한민국',
#     'global_code': '8Q7F5566+W8'},
#    'rating': 4,
#    'reference': 'ChIJERqgfIiNaDURQ9y73Ki1tdM',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 21},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 센텀3로 20',
#    'geometry': {'location': {'lat': 35.1678073, 'lng': 129.1328308},
#     'viewport': {'northeast': {'lat': 35.16915712989272,
#       'lng': 129.1341806298927},
#      'southwest': {'lat': 35.16645747010728, 'lng': 129.1314809701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '해운대센텀호텔',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111146089595775767159">A Google User</a>'],
#      'photo_reference': 'AdCG2DOk5yqWwQvvSUqwK4Jbtjgj0pVh2_tzo__BgHo1ZBWHy_r3frhQ1w9GNr_rmc5gFHOyy2cf6msexkFg4zJawk5lU79nNAhAngyOl8yNQ-nBDajtXV0mTQEDtSataRvJytfLDQXwAU-NjoKVAXvBJFIwdhW3kj1Gd7qCUQVUt95SGuey',
#      'width': 3000}],
#    'place_id': 'ChIJh0LRXMeSaDURX1YRgGSM3IM',
#    'plus_code': {'compound_code': '549M+44 부산광역시 대한민국',
#     'global_code': '8Q7F549M+44'},
#    'rating': 4,
#    'reference': 'ChIJh0LRXMeSaDURX1YRgGSM3IM',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2280},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 영도구 봉래나루로 82',
#    'geometry': {'location': {'lat': 35.094683, 'lng': 129.0391374},
#     'viewport': {'northeast': {'lat': 35.09603282989272,
#       'lng': 129.0404872298927},
#      'southwest': {'lat': 35.09333317010728, 'lng': 129.0377875701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '라발스호텔',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1374,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104471795743823129951">A Google User</a>'],
#      'photo_reference': 'AdCG2DOIiL1czRfpapFEhclF2yZGvJKxmvpBWgG0zaUWbzcTjVhZHKKzJARP4IQDL-xErU3t2SHncAiZciZpfvAy7ACgMwY7_ZDbnbXZb_YR1Lwv8L8mYFeSC8h3INFarKL2B2qSB2s2obsc6321sd-bku2iBlLQCu_6nB96bDWI-zlJsobh',
#      'width': 1920}],
#    'place_id': 'ChIJY1Avgw3paDURmnYyjP4SsVM',
#    'plus_code': {'compound_code': '32VQ+VM 부산광역시 대한민국',
#     'global_code': '8Q7F32VQ+VM'},
#    'rating': 4.5,
#    'reference': 'ChIJY1Avgw3paDURmnYyjP4SsVM',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2277},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 강서구 명지국제6로34번길 22',
#    'geometry': {'location': {'lat': 35.0907333, 'lng': 128.9020785},
#     'viewport': {'northeast': {'lat': 35.09208312989272,
#       'lng': 128.9034283298927},
#      'southwest': {'lat': 35.08938347010727, 'lng': 128.9007286701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '부산 명지 씨엘오션호텔',
#    'photos': [{'height': 2252,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103436919889879609773">Seung-Kyem Kim</a>'],
#      'photo_reference': 'AdCG2DPgAYXzuHX3TdBFIWKQqTbmSFMrqokkdyKne3-zOIfA33X7ZgIC5dc5ZygGMh1xP-n-M9dQ_jKu7bOCPIrViPx3zTTWdkiW_G5ct9QkkJcf4BRf-NEdSMdjBL-SU6DnUyoHMbF3KkKsv90oIgzvUfeHserRfL06LJmmRtbRaLxIRgNJ',
#      'width': 4000}],
#    'place_id': 'ChIJyytMkcjbaDURjqZmTNhl4Xw',
#    'plus_code': {'compound_code': '3WR2+7R 부산광역시 대한민국',
#     'global_code': '8Q7C3WR2+7R'},
#    'rating': 4.6,
#    'reference': 'ChIJyytMkcjbaDURjqZmTNhl4Xw',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 69},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 동구 대영로 265',
#    'geometry': {'location': {'lat': 35.1117624, 'lng': 129.0395994},
#     'viewport': {'northeast': {'lat': 35.11311222989273,
#       'lng': 129.0409492298927},
#      'southwest': {'lat': 35.11041257010728, 'lng': 129.0382495701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '노떼라미아호텔',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100416765114649078439">A Google User</a>'],
#      'photo_reference': 'AdCG2DN5-oS09ejqixXxkWtI_zXhqOlrkbhvW_3FtoDMa2OtVD7fT1yIaDhnZpUfnpo-ylYd0wFjfgU91ufM433dMvIJxKhA9RQH7IMeVCm0694IjZgUPRct9egzNWPCDW2b1uEgVsAUQvXWNXoUmDngEKem4PE1F-2ao0n_nvrAhgg7xP5R',
#      'width': 720}],
#    'place_id': 'ChIJJUkgKmPpaDURe3l_qCGHYWw',
#    'plus_code': {'compound_code': '426Q+PR 부산광역시 대한민국',
#     'global_code': '8Q7F426Q+PR'},
#    'rating': 4.4,
#    'reference': 'ChIJJUkgKmPpaDURe3l_qCGHYWw',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 496},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 송정해변로 32',
#    'geometry': {'location': {'lat': 35.1808298, 'lng': 129.2025405},
#     'viewport': {'northeast': {'lat': 35.18217962989272,
#       'lng': 129.2038903298927},
#      'southwest': {'lat': 35.17947997010728, 'lng': 129.2011906701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '나무늘보호텔',
#    'photos': [{'height': 3265,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103217908949940459773">송인성</a>'],
#      'photo_reference': 'AdCG2DNUWEdbvbZjq1lOh6qEEy6Af48dluFyBjDDVyiZvN-KiXoc7HYXvqibBp5lOJDAvU8EOCU-LiqSfLXApVGe8gd0JbTcmWXsYvrhCO3LfAs1in08A9PQJy_17a9EVFRQEDUadD-278hjeXNz5xxPwkJyMN_hxuM_0OFx8uJt6RvT35lU',
#      'width': 4898}],
#    'place_id': 'ChIJ7UEj7SSNaDUR7TNzP6zO30s',
#    'plus_code': {'compound_code': '56J3+82 부산광역시 대한민국',
#     'global_code': '8Q7F56J3+82'},
#    'rating': 4,
#    'reference': 'ChIJ7UEj7SSNaDUR7TNzP6zO30s',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 22},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 해운대구 중동 해운대로774번길 30',
#    'geometry': {'location': {'lat': 35.1598694, 'lng': 129.1697155},
#     'viewport': {'northeast': {'lat': 35.16121922989272,
#       'lng': 129.1710653298927},
#      'southwest': {'lat': 35.15851957010727, 'lng': 129.1683656701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '엘시티 레지던스',
#    'photos': [{'height': 877,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113032275119666685536">A Google User</a>'],
#      'photo_reference': 'AdCG2DPwg5r4d5e7Y1urH0bt0JJob1hxOeTUNRZkpEBROS5FrtD6RMRt4Sp2Xmq8uR-2OLIzbmZ-DYI1xk6VZlYluIagMTJU-lvSWpPEy9vspgP3dDb82WDDU6C_M0nv6ONae0wC2eFgSxM7C7BSzQhQU0NZFXRP66uGtexKi4Iv1VwhWwdf',
#      'width': 1441}],
#    'place_id': 'ChIJQVY5Qw2NaDURnYcLzgfOciY',
#    'plus_code': {'compound_code': '5559+WV 부산광역시 대한민국',
#     'global_code': '8Q7F5559+WV'},
#    'rating': 4.4,
#    'reference': 'ChIJQVY5Qw2NaDURnYcLzgfOciY',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 146},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 중구 중구로 151',
#    'geometry': {'location': {'lat': 35.1090506, 'lng': 129.0350539},
#     'viewport': {'northeast': {'lat': 35.11040042989271,
#       'lng': 129.0364037298927},
#      'southwest': {'lat': 35.10770077010727, 'lng': 129.0337040701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '코모도호텔 부산',
#    'photos': [{'height': 2992,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110488049196024824725">A Google User</a>'],
#      'photo_reference': 'AdCG2DOx76PIyUjLVhKEdWSVZtKziyai_rbGHfPSddfHlk2p5-VDoWJB0BDPJOXCqgE-lJSD-vZo6mMtyuVUfZAx6UCIGIGg_x1lK2h6blc3czgaWGKHG5owa5KpQZexYWLLpQsczHUFHmkAWyt0YhzN8Z5JeyOgQ1K8GAakxchNwsqwLC7l',
#      'width': 2992}],
#    'place_id': 'ChIJvRxXFnrpaDUREC-laf8KDo4',
#    'plus_code': {'compound_code': '425P+J2 부산광역시 대한민국',
#     'global_code': '8Q7F425P+J2'},
#    'rating': 4.1,
#    'reference': 'ChIJvRxXFnrpaDUREC-laf8KDo4',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2755},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '대한민국 부산광역시 영도구 해양로 38',
#    'geometry': {'location': {'lat': 35.0980223, 'lng': 129.059592},
#     'viewport': {'northeast': {'lat': 35.09937212989271,
#       'lng': 129.0609418298927},
#      'southwest': {'lat': 35.09667247010727, 'lng': 129.0582421701072}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': '그랜드베른호텔',
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101754141280250797696">Min-Jong Kim</a>'],
#      'photo_reference': 'AdCG2DP8BFKAVASyg89BKQJE6R3KejPBXVrD35vad4lGTnMPfjjziQUnlzUVJsgWV0KHkUS5pU2Nq_0UoA-v2qX3-MOLcleA9E-KOnpB2B_UPwgFEc0EqVuLmccbjui51PRTg92WaGA8ubGVcTdefx--h8PTjyLHNc7EsjE_NZZuQFs1hf8w',
#      'width': 4000}],
#    'place_id': 'ChIJS1fYG5XpaDURHUhCXQAm1oo',
#    'plus_code': {'compound_code': '33X5+6R 부산광역시 대한민국',
#     'global_code': '8Q7F33X5+6R'},
#    'rating': 4.6,
#    'reference': 'ChIJS1fYG5XpaDURHUhCXQAm1oo',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 93}],
#  'status': 'OK'}
